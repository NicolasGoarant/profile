# %% [markdown]
# <a href="https://colab.research.google.com/github/NicolasGoarant/profile/blob/gh-pages/Copie_de_Bloc3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![logo lw.png](data:image/png;base64,...)

# %% [markdown]
# ### Comparer les regressions

# %% [markdown]
# Comparez le modèle de régression linéaire et le modèle de régression logistique. Pourquoi quelles tâches sont les plus adaptées ? Quels sont leurs avantages et leurs inconvénients ?

# %% [markdown]
# Régression linéaire : prédit une valeur continue comme un prix
#
# La régression logistique prédit une classe (0 ou 1)

# %% [markdown]
# ### Justification de l'accuracy

# %% [markdown]
# Vous avez entraîné un modèle pour prédire si un produit aura du succès ou non. Vous obtenez une accuracy de 0.86. Êtes-vous satisfait ? Pourquoi ?

# %% [markdown]
# ```
# # Ce texte est au format code
# ```
# Non, car si 86 % des produits ont du succès, un modèle qui prédit toujours "succès" atteindrait déjà, 0.86 sans rien apprendre. Il faut aussi regarder le recall et la précision.

# %% [markdown]
# ### Différents pré-traitements

# %% [markdown]
# Quels sont les différents pré-traitements de données que vous connaissez ? Précisez à quel type de données ils s’appliquent et le code Python si possible.

# %% [markdown]
# StandardScaler et MinMaxScaler : les variables numériques,
#
# LabelEncoder et OneHotEncoder : les variables catégorielles,
#
# SimpleImputer : les valeurs manquantes.

# %% [markdown]
# ### Ré-équilibrer la donnée

# %% [markdown]
# Vous travaillez pour une plateforme de streaming de films. Vous voulez prédire si un film va être beaucoup regardé en fonction de ses caractéristiques.
#
#
# Votre jeu de données n’est pas balancé - vous avez 10% de vos films qui ont été peu regardés et 90% qui ont été beaucoup regardés.
#
#
# Que pouvez-vous faire pour rebalancer la donnée ? Plusieurs solutions sont possibles.

# %% [markdown]
# - dans le modèle : introduire un "class_weight = balanced
# - Oversampling avec SMOTE

# %% [markdown]
# ### Efficacité du modèle

# %% [markdown]
# Comment savoir si le prétraitement des données a amélioré l’efficacité du modèle ?

# %% [markdown]
# Il faut comparer les métriques avant et après pré-traitement sur le jeu de test.
# Si ça s'améliore, le pré-traitement a été bénéfique.

# %% [markdown]
# ### Data leakage

# %% [markdown]
# Comment éviter de faire du data leakage ? Ajoutez le code Python.

# %% [markdown]
# *Répondez ici*

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

pipeline = Pipeline([
    ("scaler", StandardScaler()),
    ("model", LogisticRegression())
])
pipeline.fit(X_train, y_train)
pipeline.score(X_test, y_test)

# %% [markdown]
# ### Etapes d'entraînement d'algorithme

# %% [markdown]
# Imaginez que vous devez entraîner un algorithme de régression linéaire.
#
# Quelles sont les différentes étapes nécessaires ?
#
# Utilisez le code Python et n’oubliez pas de préciser la bonne donnée entre donnée d’entraînement et donnée de test.

# %% [markdown]
# *Répondez ici*

# %%
1. Séparer X et y
2. diviser en train et en test
3. entraîner sur le train
4. prédire sur le test
5. évaluer avec RMSE et R2



from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

X = df[["InitialPrice", "NumberOfUnits"]]
y = df["Revenue"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

model = LinearRegression()
model.fit(X_train, y_train)

y_pred = model.predict(X_test)
print("RMSE :", mean_squared_error(y_test, y_pred, squared=False))
print("R2 :", r2_score(y_test, y_pred))

# %% [markdown]
# ### Hyper Paramètres

# %% [markdown]
# Imaginez que vous devez entraîner un KNNClassifier. Quels sont les différents hyper paramètres que vous pouvez modifier ?
#
# Choisissez-en trois et expliquez quels impacts ils auront.

# %% [markdown]
# "n_neighbors" : ça détermine le nombre de voisins. Si c'est trop petit, ça créé de l'overfitting, si c'est trop grand, ça créé de l'underfitting.
#
# "metric" : ça détermine la distance utilisée. ça influence les voisins considérés proches
#
# "weights" : ça détermine les voisins proches qui peuvent compter davantage
